# %% [markdown]
# # Analyse Exploratoire

# %% [markdown]
# ### Import des modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import missingno as msno

# %% [markdown]
# ### Analyse Exploratoire

# %%
building_consumption = pd.read_csv("2016_Building_Energy_Benchmarking.csv")

target_energy = 'SiteEnergyUse(kBtu)'
target_emissions = 'TotalGHGEmissions'

donnees_structurelles = [
    'OSEBuildingID', 'BuildingType', 'PrimaryPropertyType', 'ZipCode', 'CouncilDistrictCode',
    'Neighborhood', 'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings', 'NumberofFloors',
    'PropertyGFATotal', 'PropertyGFAParking', 'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
    'LargestPropertyUseType', 'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType',
    'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA'
]
non_structurelles = [col for col in building_consumption.columns if col not in donnees_structurelles]

# On regarde comment un batiment est défini dans ce jeu de données 
building_consumption.head()

msno.matrix(building_consumption.sample(250))
missing_values = building_consumption.isnull().mean().sort_values(ascending=False)
print("\nValeurs manquantes par colonne (%):\n", (missing_values[missing_values > 0] * 100).round(2))
# Out:
# Valeurs manquantes par colonne (%):
#  Comments                           100.00
# Outlier                             99.05
# YearsENERGYSTARCertified            96.48
# ThirdLargestPropertyUseType         82.35
# ThirdLargestPropertyUseTypeGFA      82.35
# SecondLargestPropertyUseType        50.27
# SecondLargestPropertyUseTypeGFA     50.27
# ENERGYSTARScore                     24.97
# LargestPropertyUseTypeGFA            0.59
# LargestPropertyUseType               0.59
# ZipCode                              0.47
# ListOfAllPropertyUseTypes            0.27
# SourceEUIWN(kBtu/sf)                 0.27
# SourceEUI(kBtu/sf)                   0.27
# Electricity(kWh)                     0.27
# Electricity(kBtu)                    0.27
# NaturalGas(therms)                   0.27
# NaturalGas(kBtu)                     0.27
# TotalGHGEmissions                    0.27
# SteamUse(kBtu)                       0.27
# GHGEmissionsIntensity                0.27
# ...

# %%
classification_building_consumption = pd.DataFrame({
    "Colonnes structurelles": pd.Series(donnees_structurelles),
    "Colonnes non structurelles": pd.Series(non_structurelles)
})

classification_building_consumption
# Out:
#              Colonnes structurelles     Colonnes non structurelles
# 0                     OSEBuildingID                       DataYear
# 1                      BuildingType                   PropertyName
# 2               PrimaryPropertyType                        Address
# 3                           ZipCode                           City
# 4               CouncilDistrictCode                          State
# 5                      Neighborhood  TaxParcelIdentificationNumber
# 6                          Latitude       YearsENERGYSTARCertified
# 7                         Longitude                ENERGYSTARScore
# 8                         YearBuilt               SiteEUI(kBtu/sf)
# 9                 NumberofBuildings             SiteEUIWN(kBtu/sf)
# 10                   NumberofFloors             SourceEUI(kBtu/sf)
# 11                 PropertyGFATotal           SourceEUIWN(kBtu/sf)
# 12               PropertyGFAParking            SiteEnergyUse(kBtu)
# ...

# %%
from matplotlib.patches import Patch

# 🔢 Compter les occurrences de chaque catégorie dans BuildingType
building_type_counts = building_consumption['BuildingType'].value_counts()
building_type_order = building_type_counts.index.tolist()

# Définir les couleurs en fonction de la présence de "nonresidential"
bar_colors = [
    'orange' if isinstance(bt, str) and 'nonresidential' in bt.lower() else 'blue'
    for bt in building_type_order
]

# Afficher le graphique
plt.figure(figsize=(10, 6))
building_type_counts.sort_values().plot.barh(
    color=[bar_colors[building_type_order.index(bt)] for bt in building_type_counts.sort_values().index]
)

plt.title("Répartition des types de bâtiments")
plt.xlabel("Nombre de bâtiments")
plt.ylabel("Type de bâtiment")

# Ajouter la légende en bas à droite
legend_elements = [
    Patch(facecolor='orange', label='NonResidential'),
    Patch(facecolor='blue', label='Autres')
]
plt.legend(handles=legend_elements, title="Catégories", loc='lower right')

plt.tight_layout()
plt.show()

# Afficher le nombre de lignes avant filtrage
print("Nombre de lignes avant filtrage:", building_consumption.shape[0])
# 2️⃣ Filtrer uniquement les bâtiments NonResidential
building_consumption = building_consumption[building_consumption['BuildingType'].str.contains("nonresidential", case=False, na=False)]
print("Nombre de lignes après filtrage (seulement NonResidential):", building_consumption.shape[0])
# Out:
# Nombre de lignes avant filtrage: 3376
# Nombre de lignes après filtrage (seulement NonResidential): 1546

# %%
cols_utiles = [
    'SiteEnergyUse(kBtu)', 'TotalGHGEmissions', 'ENERGYSTARScore',
    'YearBuilt', 'NumberofFloors', 'PropertyGFATotal', 'Outlier', 'ComplianceStatus'
]
df_clean = building_consumption[cols_utiles].copy()

# Histogrammes pour visualiser les distributions
fig, axes = plt.subplots(3, 2, figsize=(14, 12))
df_clean['SiteEnergyUse(kBtu)'].hist(ax=axes[0, 0], bins=50)
axes[0, 0].set_title("SiteEnergyUse(kBtu)")

df_clean['TotalGHGEmissions'].hist(ax=axes[0, 1], bins=50)
axes[0, 1].set_title("TotalGHGEmissions")

df_clean['ENERGYSTARScore'].hist(ax=axes[1, 0], bins=25)
axes[1, 0].set_title("ENERGYSTARScore")

df_clean['YearBuilt'].hist(ax=axes[1, 1], bins=50)
axes[1, 1].set_title("YearBuilt")

df_clean['NumberofFloors'].hist(ax=axes[2, 0], bins=30)
axes[2, 0].set_title("NumberofFloors")

df_clean['PropertyGFATotal'].hist(ax=axes[2, 1], bins=50)
axes[2, 1].set_title("PropertyGFATotal")

plt.tight_layout()
plt.show()

# Aperçu des outliers ou valeurs aberrantes
print("\nValeurs aberrantes détectées :")
print("Année de construction < 1800 ou > 2025 :")
print(building_consumption[(building_consumption['YearBuilt'] < 1800) | (building_consumption['YearBuilt'] > 2025)][['YearBuilt']])

print("\nBâtiments avec 0 étage ou > 100 étages :")
print(building_consumption[(building_consumption['NumberofFloors'] <= 0) | (building_consumption['NumberofFloors'] > 100)][['NumberofFloors']])

print("\nConsommation ou émission nulle :")
print(building_consumption[(building_consumption['SiteEnergyUse(kBtu)'] <= 0) | (building_consumption['TotalGHGEmissions'] <= 0)][['SiteEnergyUse(kBtu)', 'TotalGHGEmissions']])

print("\nBâtiments marqués comme outliers :")
print(building_consumption[building_consumption['Outlier'].notna()][['Outlier']].value_counts())

# Supprimer les valeurs aberrantes
conditions_aberrantes = (
    (building_consumption['YearBuilt'] < 1800) | (building_consumption['YearBuilt'] > 2025) |
    (building_consumption['NumberofFloors'] <= 0) | (building_consumption['NumberofFloors'] > 100) |
    (building_consumption['SiteEnergyUse(kBtu)'] <= 0) |
    (building_consumption['TotalGHGEmissions'] < 0)
)
nb_avant = building_consumption.shape[0]
building_consumption = building_consumption[~conditions_aberrantes].copy()
nb_apres = building_consumption.shape[0]

# Résumé du nettoyage
print(f"✅ Lignes avant nettoyage : {nb_avant}")
print(f"✅ Lignes après nettoyage : {nb_apres}")
print(f"🗑️ Lignes supprimées : {nb_avant - nb_apres}")
# Out:
# Valeurs aberrantes détectées :
# Année de construction < 1800 ou > 2025 :
# Empty DataFrame
# Columns: [YearBuilt]
# Index: []
#
# Bâtiments avec 0 étage ou > 100 étages :
#       NumberofFloors
# 166                0
# 487                0
# 488                0
# 564                0
# 1754               0
# 3130               0
# 3131               0
# 3132               0
# 3168               0
# 3273               0
# 3276               0
# 3278               0
# 3279               0
# 3280               0
#
# Consommation ou émission nulle :
#       SiteEnergyUse(kBtu)  TotalGHGEmissions
# 304          0.000000e+00                0.0
# 513          1.252517e+07                0.0
# 746          0.000000e+00                0.0
# 3206         3.427261e+05               -0.8
#
# Bâtiments marqués comme outliers :
# Outlier
# Low outlier     14
# High outlier     2
# Name: count, dtype: int64
# ✅ Lignes avant nettoyage : 1546
# ✅ Lignes après nettoyage : 1529
# ...

# %%
cols_to_check = [
    'PropertyGFABuilding(s)', 
    'LargestPropertyUseTypeGFA', 
    'SecondLargestPropertyUseTypeGFA', 
    'ThirdLargestPropertyUseTypeGFA'
]

# 3️⃣ Extraire les colonnes concernées
df_use = building_consumption[cols_to_check].copy()

# 4️⃣ Calcul de la somme des usages déclarés (en remplaçant les NaN par 0)
df_use['Somme_GFAs'] = df_use[
    ['LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseTypeGFA']
].fillna(0).sum(axis=1)

# 5️⃣ Calcul de l'écart entre surface déclarée et somme des usages
df_use['Ecart'] = df_use['PropertyGFABuilding(s)'] - df_use['Somme_GFAs']

# 6️⃣ Affichage des graphes
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# ➤ Scatter plot : Surface déclarée vs Somme des usages
axes[0].scatter(df_use['PropertyGFABuilding(s)'], df_use['Somme_GFAs'], alpha=0.5)
axes[0].plot([0, df_use['PropertyGFABuilding(s)'].max()],
             [0, df_use['PropertyGFABuilding(s)'].max()], 'r--')
axes[0].set_xlabel("Surface totale déclarée (PropertyGFABuilding(s))")
axes[0].set_ylabel("Somme des usages GFA")
axes[0].set_title("Comparaison Surface Totale vs Somme des Usages")

# ➤ Histogramme des écarts
axes[1].hist(df_use['Ecart'].dropna(), bins=50)
axes[1].set_xlabel("Écart (surface déclarée - somme usages)")
axes[1].set_ylabel("Nombre de bâtiments")
axes[1].set_title("Distribution des écarts de surface")

plt.tight_layout()
plt.show()

# %%
#building_consumption.loc[building_consumption['OSEBuildingID'].duplicated(keep=False),:]
building_consumption.describe()
# Out:
#        OSEBuildingID  DataYear       ZipCode  CouncilDistrictCode  \
# count    3376.000000    3376.0   3360.000000          3376.000000
# mean    21208.991114    2016.0  98116.949107             4.439277
# std     12223.757015       0.0     18.615205             2.120625
# min         1.000000    2016.0  98006.000000             1.000000
# 25%     19990.750000    2016.0  98105.000000             3.000000
# 50%     23112.000000    2016.0  98115.000000             4.000000
# 75%     25994.250000    2016.0  98122.000000             7.000000
# max     50226.000000    2016.0  98272.000000             7.000000
#
#           Latitude    Longitude    YearBuilt  NumberofBuildings  \
# count  3376.000000  3376.000000  3376.000000        3368.000000
# mean     47.624033  -122.334795  1968.573164           1.106888
# std       0.047758     0.027203    33.088156           2.108402
# min      47.499170  -122.414250  1900.000000           0.000000
# ...

# %%
# On regarde comment un batiment est défini dans ce jeu de données 
building_consumption.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)  \
# 0                    0659000030  ...      1.156514e+06         3946027.0
# ...

# %%
# On regarde le nombre de valeurs manquantes par colonne ainsi que leur type 
building_consumption.info()

# %% [markdown]
# #### TERMINER L'ANALYSE EXPLORATOIRE

# %% [markdown]
# A réaliser :
# - Une analyse descriptive des données, y compris une explication du sens des colonnes gardées, des arguments derrière la suppression de lignes ou de colonnes, des statistiques descriptives et des visualisations pertinentes.

# %% [markdown]
# Qelques pistes d'analyse :

# %% [markdown]
# * Identifier les colonnes avec une majorité de valeurs manquantes ou constantes en utilisant la méthode value_counts() de Pandas
# * Mettre en evidence les différences entre les immeubles mono et multi-usages
# * Utiliser des pairplots et des boxplots pour faire ressortir les outliers ou des batiments avec des valeurs peu cohérentes d'un point de vue métier

# %% [markdown]
# Pour vous inspirer, ou comprendre l'esprit recherché dans une analyse exploratoire, vous pouvez consulter ce notebook en ligne : https://www.kaggle.com/code/pmarcelino/comprehensive-data-exploration-with-python. Il ne s'agit pas d'un modèle à suivre à la lettre ni d'un template d'analyses attendues pour ce projet.

# %% [markdown]
# # Modélisation

# %% [markdown]
# ### Import des modules

# %%
#Selection
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV, 
    cross_validate,
)
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error 
from sklearn.inspection import permutation_importance

#Preprocess
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

#Modèles
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# A réaliser : Enrichir le jeu de données actuel avec de nouvelles features issues de celles existantes.

# %% [markdown]
# En règle générale : On utilise la méthode .apply() de Pandas pour créer une nouvelle colonne à partir d'une colonne existante. N'hésitez pas à regarder les exemples dans les chapitres de cours donnés en ressource

# %%
# CODE FEATURE ENGINEERING

# %% [markdown]
# ### Préparation des features pour la modélisation

# %% [markdown]
# A réaliser :
# * Si ce n'est pas déjà fait, supprimer toutes les colonnes peu pertinentes pour la modélisation.
# * Tracer la distribution de la cible pour vous familiariser avec l'ordre de grandeur. En cas d'outliers, mettez en place une démarche pour les supprimer.
# * Débarrassez-vous des features redondantes en utilisant une matrice de corrélation de Pearson. Pour cela, utiisez la méthode corr() de Pandas, couplé d'un graphique Heatmap de la librairie Seaborn
# * Réalisez différents graphiques pour comprendre le lien entre vos features et la target (boxplots, scatterplots, pairplot si votre nombre de features numériques n'est pas très élevé).
# *  Séparez votre jeu de données en un Pandas DataFrame X (ensemble de feautures) et Pandas Series y (votre target).
# * Si vous avez des features catégorielles, il faut les encoder pour que votre modèle fonctionne. Les deux méthodes d'encodage à connaitre sont le OneHotEncoder et le LabelEncoder

# %%
# CODE PREPARATION DES FEATURES

# %% [markdown]
# ### Comparaison de différents modèles supervisés

# %% [markdown]
# A réaliser :
# * Pour chaque algorithme que vous allez tester, vous devez :
#     * Réaliser au préalable une séparation en jeu d'apprentissage et jeu de test via une validation croisée.
#     * Si les features quantitatives que vous souhaitez utiliser ont des ordres de grandeur très différents les uns des autres, et que vous utilisez un algorithme de regression qui est sensible à cette différence, alors il faut réaliser un scaling (normalisation) de la donnée au préalable.
#     * Entrainer le modèle sur le jeu de Train
#     * Prédire la cible sur la donnée de test (nous appelons cette étape, l'inférence).
#     * Calculer les métriques de performance R2, MAE et RMSE sur le jeu de train et de test.
#     * Interpréter les résultats pour juger de la fiabilité de l'algorithme.
# * Vous pouvez choisir par exemple de tester un modèle linéaire, un modèle à base d'arbres et un modèle de type SVM
# * Déterminer le modèle le plus performant parmi ceux testés.

# %%
# CODE COMPARAISON DES MODELES

# %% [markdown]
# ### Optimisation et interprétation du modèle

# %% [markdown]
# A réaliser :
# * Reprennez le meilleur algorithme que vous avez sécurisé via l'étape précédente, et réalisez une GridSearch de petite taille sur au moins 3 hyperparamètres.
# * Si le meilleur modèle fait partie de la famille des modèles à arbres (RandomForest, GradientBoosting) alors utilisez la fonctionnalité feature importance pour identifier les features les plus impactantes sur la performance du modèle. Sinon, utilisez la méthode Permutation Importance de sklearn.

# %%
# CODE OPTIMISATION ET INTERPRETATION DU MODELE
